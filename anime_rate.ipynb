# %%
import pandas as pd
anime = pd.read_csv(r'C:\Users\user\Desktop\anime rate\anime.csv')
anime = anime.loc[(anime['type'] == "TV") & (anime['rating'] >= 8)]
anime
#anime.to_excel('./anime_with_rates.xlsx', index = False)
# Out:
#        anime_id                                               name  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# ...         ...                                                ...
# 10498     32585                                        Telemonster
# 10718     22219                               Warera Salaryman Tou
# 10734     19839                                 Wei Qi Shao Nian 2
# 10765     32230                                          Xi You Ji
# 10831     23351                             Youkaiden Nekome Kozou
#
#                                                    genre type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# ...
